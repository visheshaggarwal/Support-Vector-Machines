# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Preparing Dataset

# %%
X,Y = make_circles(n_samples=500,noise=0.02)
print(X.shape)
print(Y.shape)
# Out:
# (500, 2)
# (500,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %% [markdown]
# ### Changing the dimensions of the Dataset

# %%
def phi(X):
    """Non Linear Transformation"""
    X1 = X[:,0]
    X2 = X[:,1]
    X3 = X1**2 + X2**2
    
    X_ = np.zeros((X.shape[0],3))
    X_[:,:-1] = X
    X_[:,-1] = X3
    
    return X_

# %%
X_ = phi(X)
print(X_.shape)
# Out:
# (500, 3)

# %%
def plot3d(X):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111,projection='3d')
    X1 = X[:,0]
    X2 = X[:,1]    
    X3 = X[:,2]
    
    ax.scatter(X1,X2,X3,zdir='z',s=20,c=Y,depthshade = True)
    plt.show()
    return ax

# %%
ax = plot3d(X_)

# %% [markdown]
# ### Logistic Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
lr = LogisticRegression?

# %%
lr = LogisticRegression

# %%
lr = LogisticRegression()

# %%
acc = cross_val_score(lr,X_,Y,cv=5).mean()
print("Accuracy is %.4f"%(acc*100))
# Out:
# Accuracy is 100.0000
# c:\users\seema\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\seema\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\seema\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\seema\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\seema\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
